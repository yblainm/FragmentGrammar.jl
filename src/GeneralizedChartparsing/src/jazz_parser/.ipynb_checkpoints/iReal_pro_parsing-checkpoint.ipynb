# %%
srand(1234)
addprocs(4)
# Out:
# 4-element Array{Int64,1}:
#  2
#  3
#  4
#  5

# %%
@everywhere include("newtrees.jl")
@everywhere using Trees

@everywhere using AccessMacro
@everywhere using Missings
@everywhere using LogProbs
@everywhere using DataStructures
@everywhere using DataFrames

@everywhere using StatsFuns.RFunctions: gammarand

@everywhere using LightGraphs: Graph, add_vertex!, add_edge!, nv

@everywhere import TikzGraphs: plot
@everywhere import Base: show, hash, ==
@everywhere import Base: +, -, *, /, zero, one, <
@everywhere import Base: start, length, insert!, isempty, convert, getindex, promote_rule, range
@everywhere import DataStructures: enqueue!, dequeue!

# %%
import Plots

# %% [markdown]
# # iReal pro parsing -- My ISMIR paper 2018
#
# ## Load parser, grammar, & data and plot first parse tree

# %%
@everywhere cd("/Users/daniel/Documents/GitHub/GeneralizedChartparsing")
@everywhere include("src/jazz_parser/newjazz.jl")
# Out:
# number_chord_symbols = size(vcat(iReal_songs[:chords]...)) = (59396, 8)
# (terminals(iReal_songs[4, :chords]))[1:13] = JazzTerminal[C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^]
# 	From worker 5:	number_chord_symbols = size(vcat(iReal_songs[:chords]...)) = (59396, 8)
# 	From worker 4:	number_chord_symbols = size(vcat(iReal_songs[:chords]...)) = (59396, 8)
# 	From worker 3:	number_chord_symbols = size(vcat(iReal_songs[:chords]...)) = (59396, 8)
# 	From worker 2:	number_chord_symbols = size(vcat(iReal_songs[:chords]...)) = (59396, 8)
# 	From worker 4:	(terminals(iReal_songs[4, :chords]))[1:13] = JazzTerminal[C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^]
# 	From worker 5:	(terminals(iReal_songs[4, :chords]))[1:13] = JazzTerminal[C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^]
# 	From worker 3:	(terminals(iReal_songs[4, :chords]))[1:13] = JazzTerminal[C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^]
# 	From worker 2:	(terminals(iReal_songs[4, :chords]))[1:13] = JazzTerminal[C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^, Am7, Dm7, G7, C^]

# %%
chords = terminals(iReal_songs[4, :chords])[1:13]
grammar = init_jazz_grammar()
@time forest = run_chartparser(chords, grammar);
sample_tree(forest)
# Out:
#   2.661115 seconds (4.35 M allocations: 188.325 MiB, 4.52% gc time)
# [I_{a}[III_{a}[III_{a}[C^]][III_{a}[III_{a}[III_{a}[I_{C}[V_{C}[II_{C}[V_{d}[I_{a}[Am7]]][II_{C}[Dm7]]][V_{C}[G7]]][I_{C}[C^]]]][III_{a}[V_{C}[II_{C}[VI_{C}[Am7]][II_{C}[Dm7]]][V_{C}[G7]]][III_{a}[C^]]]][III_{a}[V_{C}[II_{C}[VI_{C}[Am7]][II_{C}[Dm7]]][V_{C}[G7]]][III_{a}[C^]]]]]]

# %%
"""
    unzip(iter)

unzip an iterable object of indexable objects
"""
function unzip(iter)
    ntuple(length(first(iter))) do i
        map(iter) do indexable
            getindex(indexable, i)
        end
    end
end
        
# test
unzip([(1,2,3), (11,22,33)]) == ([1, 11], [2, 22], [3, 33])
# Out:
# true

# %%
function rules_df(grammar) 
    lst = [
        (replace(string(components), '_', ", "), count, string(rule))
        for components in keys(grammar.cond.dists)
        for (rule, count) in grammar.cond.dists[components].counts
    ]
    
    df = DataFrame(collect(unzip(lst)), [:components, :count, :rule])
    sort(df, cols=[order(:components), order(:count, rev=true)])
end
# Out:
# rules_df (generic function with 1 method)

# %%
DataFrames.head(rules_df(grammar))
# Out:
# 6×3 DataFrames.DataFrame
# │ Row │ components     │ count    │ rule                    │
# ├─────┼────────────────┼──────────┼─────────────────────────┤
# │ 1   │ "(I, \"major\")" │ 1.0      │ "CFRule(diatonic_prep)" │
# │ 2   │ "(I, \"major\")" │ 1.0      │ "CFRule(prolongation)"  │
# │ 3   │ "(I, \"major\")" │ 1.0      │ "CFRule(diatonic_subs)" │
# │ 4   │ "(I, \"major\")" │ 1.0      │ "CFRule(plagal_prep)"   │
# │ 5   │ "(I, \"major\")" │ 1.0      │ "CFRule(mode_change)"   │
# │ 6   │ "(I, \"major\")" │ 0.333333 │ "CFRule(6_termination)" │

# %%
size(rules_df(grammar))
# Out:
# (107, 3)

# %% [markdown]
# ## Prior Accuracies

# %%
meta_grammar_prior = init_jazz_grammar()
plain_grammar_prior = init_jazz_grammar(identity);

# %%
lines = readlines("/Users/daniel/Documents/GitHub/iRealPro/compiled_tree_data.txt")
gold_names  = lines[collect(1:3:length(lines))]
gold_leafss = eval.(parse.(lines[collect(2:3:length(lines))]))
gold_trees  = tree.(lines[collect(3:3:length(lines))]);

# %%
t = sample_tree(run_chartparser(gold_leafss[1], meta_grammar_prior))
# Out:
# [I_{a}[III_{a}[III_{a}[C^7]][III_{a}[III_{a}[C^7]][III_{a}[VII_{a}[V_{G}[II_{G}[II_{G}[I_{a}[IV_{a}[V_{d}[V_{a}[V_{a}[E7]][V_{a}[E7]]][V_{d}[A7]]][IV_{a}[V_{d}[A7]][IV_{a}[IV_{a}[Dm7]][IV_{a}[Dm7]]]]][I_{a}[V_{a}[E7]][I_{a}[V_{a}[E7]][I_{a}[I_{A}[I_{a}[Am7]]]]]]]][II_{G}[Am7]]][V_{G}[V_{G}[D7]][V_{G}[D7]]]][VII_{a}[IV_{a}[Dm7]][VII_{a}[G7]]]][III_{a}[III_{a}[III_{a}[I_{C}[C^7]]][III_{a}[C^7]]][III_{a}[V_{C}[II_{C}[V_{d}[V_{a}[V_{f#}[VII_{f#}[VII_{f#}[E7]][VII_{f#}[E7]]]]][V_{d}[V_{f}[V_{b}[V_{d}[A7]]]]]][II_{C}[II_{C}[II_{C}[V_{d}[A7]][II_{C}[I_{d}[Dm7]]]][II_{C}[Dm7]]][II_{C}[IV_{C}[F^7]]]]][V_{C}[V_{Eb}[Fm6]]]][III_{a}[VII_{a}[VII_{a}[I_{G}[VI_{G}[Em7]]]][VII_{a}[IV_{a}[V_{d}[A7]][IV_{a}[Dm7]]][VII_{a}[G7]]]][III_{a}[C6]]]]]]]]]

# %%
@everywhere function boolean_dependency_matrix(t::Tree)
    map(x-> x == "" ? false : true, dependency_matrix(t))
end

@everywhere function dependency_matrix(t::Tree)
    t = map(x->"x", t)
    k = add_leaf_indices!(t)
    add_inner_dependency_indices!(t)

    M = ["" for i in 1:k, j in 1:k]
    for node in t
        m = match(r"(.+) (\d+) (\d+)", node.data)
        M[parse(m[2]), parse(m[3])] = m[1]
    end
    M
end

@everywhere function add_leaf_indices!(tree::Tree)
    k = 1
    for node in tree
        if isleaf(node)
            node.data *= " $k $(k+1)"
            k += 1
        end
    end
    k # highest indices
end

@everywhere function add_inner_dependency_indices!(treenode::Tree)
    if !isleaf(treenode)
        m1 = match(r" (\d+) (\d+)", add_inner_dependency_indices!(treenode.children[1]).data)
        m2 = match(r" (\d+) (\d+)", add_inner_dependency_indices!(treenode.children[end]).data)
        treenode.data *= " $(m1[1]) $(m2[2])"
    end
    treenode
end

@everywhere Base.precision(proposal, goldstandard) =
    num_common_cons(proposal, goldstandard) / num_cons(proposal)
@everywhere recall(proposal, goldstandard) =
    num_common_cons(proposal, goldstandard) / num_cons(goldstandard)
@everywhere f1_measure(proposal, goldstandard) =
    2 * precision(proposal, goldstandard) * recall(proposal, goldstandard) /
       (precision(proposal, goldstandard) + recall(proposal, goldstandard))

@everywhere function num_cons(tree::Tree)
    M = boolean_dependency_matrix(tree)
    count(M) - size(M, 1)
end

@everywhere function num_common_cons(tree1::Tree, tree2::Tree)
    A = boolean_dependency_matrix(tree1)
    B = boolean_dependency_matrix(tree2)
    sum(a && b for (a,b) in zip(A,B)) - size(A, 1)
end

# %%
@time meta_prior_accs = pmap(gold_leafss, gold_trees) do ls, t
    precision(convert(Tree, best_tree(run_chartparser(ls, meta_grammar_prior))), t)
end
# Out:
#  28.639832 seconds (1.96 M allocations: 88.360 MiB, 0.26% gc time)
# 13-element Array{Float64,1}:
#  0.0689655
#  0.615385
#  0.230769
#  0.290323
#  0.230769
#  0.431034
#  0.533333
#  0.309091
#  0.353846
#  0.444444
#  0.387755
#  0.490566
#  0.333333

# %%
mean(meta_prior_accs)
# Out:
# 0.36304730549177516

# %%
@time plain_prior_accs = pmap(gold_leafss, gold_trees) do ls, t
    precision(convert(Tree, best_tree(run_chartparser(ls, plain_grammar_prior))), t)
end
# Out:
#  20.813923 seconds (774.53 k allocations: 21.758 MiB, 0.07% gc time)
# 13-element Array{Float64,1}:
#  0.0689655
#  0.615385
#  0.230769
#  0.290323
#  0.230769
#  0.431034
#  0.533333
#  0.309091
#  0.353846
#  0.444444
#  0.387755
#  0.490566
#  0.333333

# %%
mean(plain_prior_accs)
# Out:
# 0.36304730549177516

# %% [markdown]
# ## Inference

# %%
@everywhere using Counters

@everywhere function approx_expected_rule_usage(forest, grammar; number_samples=10*length(terminals(forest)))
    rule_usage_by_tree = map([sample_tree(forest).rules for _ in 1:number_samples]) do rules
        rule_counts = Counters.counter(
            map(rules) do category_and_rule
                c, r = category_and_rule
                dependent_components(grammar, c), r
            end
        )
        # Dict(r => log(c) for (r, c) in rule_counts)
    end
    
    Dict(
        k => v / number_samples
        for (k, v) in merge(+, rule_usage_by_tree...)
    )
end

batches(ss, batch_size) = [
    ss[(k * batch_size + 1):(k * batch_size + batch_size)]
    for k in 0:div(length(ss), batch_size)-1
]

# forgetting rate ∈ (0.5,1], delay ≧ 0
step_size(i; delay=10, forgetting_rate=0.9) = (i + delay)^(-forgetting_rate)

*(d::Dict, λ::Number) = Dict(k => λ*v for (k, v) in d)
# Out:
# * (generic function with 250 methods)

# %%
function do_inference!(
        grammar = init_jazz_grammar(),
        outer_loop = 2,
        batch_size = 8,
        minimal_sequence_length = 1,
        maximal_sequence_length = 40,
    )
    
    # get the data
    sequence_lengths = size.(iReal_songs[:chords], 1)
    sequences = sort(
        terminals.(
            iReal_songs[
                find(sequence_lengths) do n
                    minimal_sequence_length <= n <= maximal_sequence_length
                end, 
                :chords
            ]
        ),
        by=length
    )
    @show length(sequences)

    # initialize output table
    rules_data = rules_df(grammar)
    rules_data[:step] = -1
    DataFrames.head(rules_data)

    parsable = SharedVector{Bool}(length(sequences))

    # create and observe initial parse trees
    @time for (i, batch) in enumerate(batches(sequences, batch_size))
        print("$i/$(div(length(sequences), batch_size))\t$(length.(batch))\t")
        @time initial_parse_trees = pmap(enumerate(batch)) do index_and_sequence
            k, s = index_and_sequence
            forest = run_chartparser(s, init_jazz_grammar(), cyclic=true)
            parsable[(i-1)*batch_size + k] = iscomplete(forest)
            iscomplete(forest) ? sample_tree(forest) : missing
        end

        for t in initial_parse_trees[.!ismissing.(initial_parse_trees)]
            for (c, r) in t.rules
                grammar.cond.dists[dependent_components(grammar, c)].counts[r] += 1
            end
        end
    end

    df = rules_df(grammar)
    df[:step] = 0
    rules_data = vcat(rules_data, df)

    # compile parsable sequences
    ss = sequences[parsable]
    L = length(sequences)
    N = length(ss)
    println((L-mod(L, batch_size), N, N / (L-mod(L, batch_size))))
    println()
    
    m = mean(pmap(gold_leafss, gold_trees) do ls, t
        precision(convert(Tree, best_tree(run_chartparser(ls, grammar))), t)
    end)
    println("mean tree accuracy: $m")
    println()
    
    @time for j in 0:outer_loop-1
        println("outer loop $(j+1)")
        @time for (i, batch) in enumerate(shuffle(batches(ss, batch_size)))
            step = j * div(N, batch_size) + i
            α    = step_size(step)
            print("$i/$(div(N, batch_size)) ")

            rule_usage_by_sequence = pmap(shuffle(batch)) do s
                approx_expected_rule_usage(run_chartparser(s, grammar, cyclic=true), grammar)
            end

            total_rule_usage = merge(+, rule_usage_by_sequence...) * (N/batch_size)

            for c in keys(grammar.cond.dists)
                for r in keys(grammar.cond.dists[c].counts)
                    grammar.cond.dists[c].counts[r] = 
                        (1-α) * grammar.cond.dists[c].counts[r] + 
                           α  * (haskey(total_rule_usage, (c, r)) ? total_rule_usage[c, r] : 0.0)
                end
            end

            df = rules_df(grammar)
            df[:step] = step
            rules_data = vcat(rules_data, df)

            grammar_type = grammar.dependent_components == identity ? "plain" : "meta"
            
            writetable(
                "src/jazz_parser/rules_data_min$(minimal_sequence_length)_max$(maximal_sequence_length)_$(grammar_type).tsv", 
                rules_data
            )
        end

        m = mean(pmap(gold_leafss, gold_trees) do ls, t
            precision(convert(Tree, best_tree(run_chartparser(ls, grammar))), t)
        end)
        println("mean tree accuracy: $m")
        println()
    end
    grammar
end
# Out:
# do_inference! (generic function with 6 methods)

# %%
meta_grammar = do_inference!(init_jazz_grammar());
# Out:
# length(sequences) = 394
# 1/49	[7, 11, 12, 12, 12, 12, 12, 12]	 10.592533 seconds (709.10 k allocations: 29.305 MiB, 0.13% gc time)
# 2/49	[12, 12, 12, 12, 12, 12, 12, 12]	  6.769583 seconds (1.34 M allocations: 33.132 MiB, 0.60% gc time)
# 3/49	[12, 12, 12, 12, 13, 13, 13, 13]	  5.567596 seconds (204.25 k allocations: 5.460 MiB)
# 4/49	[14, 14, 14, 14, 14, 14, 14, 15]	  8.147771 seconds (2.08 M allocations: 51.512 MiB, 0.81% gc time)
# 5/49	[15, 15, 15, 16, 16, 16, 16, 16]	  7.983079 seconds (2.04 M allocations: 50.881 MiB, 1.05% gc time)
# 6/49	[16, 16, 16, 16, 16, 16, 16, 16]	  9.546764 seconds (4.23 M allocations: 102.235 MiB, 4.35% gc time)
# 7/49	[16, 16, 16, 16, 16, 16, 16, 16]	  6.951778 seconds (3.73 M allocations: 86.521 MiB, 2.30% gc time)
# 8/49	[16, 16, 17, 17, 17, 17, 17, 17]	 11.212878 seconds (5.99 M allocations: 139.240 MiB, 3.94% gc time)
# 9/49	[17, 17, 18, 18, 18, 18, 18, 18]	 12.025590 seconds (9.53 M allocations: 218.362 MiB, 5.69% gc time)
# 10/49	[18, 18, 18, 18, 19, 19, 19, 19]	  9.555467 seconds (5.22 M allocations: 121.523 MiB, 5.36% gc time)
# 11/49	[19, 20, 20, 20, 20, 20, 20, 20]	 13.307718 seconds (9.68 M allocations: 224.007 MiB, 7.58% gc time)
# 12/49	[20, 20, 20, 20, 20, 20, 20, 20]	 11.283738 seconds (9.12 M allocations: 205.599 MiB, 5.77% gc time)
# 13/49	[20, 21, 22, 22, 22, 22, 23, 23]	 18.914037 seconds (16.28 M allocations: 375.666 MiB, 7.90% gc time)
# 14/49	[23, 23, 23, 23, 23, 24, 24, 24]	 17.340299 seconds (10.50 M allocations: 246.242 MiB, 5.57% gc time)
# 15/49	[24, 24, 24, 24, 24, 24, 24, 24]	 16.959031 seconds (15.31 M allocations: 357.530 MiB, 8.42% gc time)
# 16/49	[24, 24, 24, 24, 24, 24, 25, 25]	 15.089668 seconds (14.75 M allocations: 341.902 MiB, 10.07% gc time)
# 17/49	[25, 25, 25, 25, 25, 26, 26, 26]	 23.958216 seconds (22.66 M allocations: 515.481 MiB, 11.54% gc time)
# 40/49	[37, 37, 38, 38, 38, 38, 38, 38]	 50.439214 seconds (51.70 M allocations: 1.113 GiB, 18.65% gc time)
# 41/49	[38, 38, 38, 38, 38, 38, 38, 38]	 42.107690 seconds (43.89 M allocations: 978.678 MiB, 19.93% gc time)
# 42/49	[38, 38, 38, 38, 38, 38, 38, 38]	 65.253713 seconds (54.76 M allocations: 1.183 GiB, 14.19% gc time)
# 43/49	[38, 38, 38, 38, 38, 38, 38, 38]	 47.920328 seconds (48.42 M allocations: 1.045 GiB, 22.00% gc time)
# 44/49	[38, 39, 39, 39, 39, 39, 39, 39]	 60.878299 seconds (55.10 M allocations: 1.191 GiB, 18.20% gc time)
# 45/49	[39, 39, 39, 39, 39, 39, 39, 39]	 53.380677 seconds (54.80 M allocations: 1.176 GiB, 20.53% gc time)
# 46/49	[39, 39, 39, 39, 39, 39, 40, 40]	 52.725119 seconds (45.25 M allocations: 998.838 MiB, 16.16% gc time)
# 47/49	[40, 40, 40, 40, 40, 40, 40, 40]	 65.147948 seconds (63.91 M allocations: 1.364 GiB, 18.07% gc time)
# 48/49	[40, 40, 40, 40, 40, 40, 40, 40]	 71.912496 seconds (55.78 M allocations: 1.195 GiB, 17.05% gc time)
# 49/49	[40, 40, 40, 40, 40, 40, 40, 40]	 71.758620 seconds (60.64 M allocations: 1.311 GiB, 17.21% gc time)
# 1580.820949 seconds (1.42 G allocations: 30.965 GiB, 14.44% gc time)
# (392, 357, 0.9107142857142857)
#
# mean tree accuracy: 0.42409667048406796
#
# outer loop 1
# 1/44 2/44 3/44 4/44 5/44 6/44 7/44 8/44 9/44 10/44 11/44 12/44 13/44 14/44 15/44 16/44 17/44 18/44 19/44 20/44 21/44 22/44 23/44 24/44 25/44 26/44 27/44 28/44 29/44 30/44 31/44 32/44 33/44 34/44 35/44 36/44 37/44 38/44 39/44 40/44 41/44 42/44 43/44 44/44 1232.739966 seconds (49.54 M allocations: 1.363 GiB, 0.10% gc time)
# mean tree accuracy: 0.44701095892429277
#
# outer loop 2
# 1/44 2/44 3/44 4/44 5/44 6/44 7/44 8/44 9/44 10/44 11/44 12/44 13/44 14/44 15/44 16/44 17/44 18/44 19/44 20/44 21/44 22/44 23/44 24/44 25/44 26/44 27/44 28/44 29/44 30/44 31/44 32/44 33/44 34/44 35/44 36/44 37/44 38/44 39/44 40/44 41/44 42/44 43/44 44/44 1193.161930 seconds (50.82 M allocations: 1.363 GiB, 0.17% gc time)
# mean tree accuracy: 0.4549048200995778
#
# 2471.903569 seconds (103.39 M allocations: 2.803 GiB, 0.14% gc time)

# %%
plain_grammar = do_inference!(init_jazz_grammar(identity));
# Out:
# length(sequences) = 394
# 1/49	[7, 11, 12, 12, 12, 12, 12, 12]	  4.015456 seconds (489.50 k allocations: 14.538 MiB, 0.42% gc time)
# 2/49	[12, 12, 12, 12, 12, 12, 12, 12]	  4.152740 seconds (1.31 M allocations: 31.182 MiB, 1.61% gc time)
# 3/49	[12, 12, 12, 12, 13, 13, 13, 13]	  3.187906 seconds (245.67 k allocations: 5.890 MiB)
# 26/49	[33, 33, 33, 33, 33, 33, 33, 33]	 24.376145 seconds (27.56 M allocations: 625.567 MiB, 16.29% gc time)
# 27/49	[33, 33, 34, 34, 34, 34, 34, 34]	 34.750571 seconds (33.50 M allocations: 759.775 MiB, 16.41% gc time)
# 28/49	[34, 34, 34, 34, 34, 34, 34, 34]	 36.450467 seconds (34.24 M allocations: 766.886 MiB, 13.71% gc time)
# 29/49	[34, 34, 34, 34, 35, 35, 35, 35]	 42.927387 seconds (42.75 M allocations: 950.996 MiB, 17.74% gc time)
# 30/49	[35, 35, 35, 35, 35, 35, 35, 35]	 33.765828 seconds (29.72 M allocations: 665.463 MiB, 12.42% gc time)
# 31/49	[35, 35, 35, 35, 35, 35, 35, 35]	 32.096569 seconds (25.85 M allocations: 581.048 MiB, 12.77% gc time)
# 32/49	[35, 35, 35, 35, 35, 35, 35, 35]	 32.684770 seconds (37.28 M allocations: 835.280 MiB, 18.13% gc time)
# 33/49	[35, 35, 35, 35, 36, 36, 36, 36]	 32.578435 seconds (34.40 M allocations: 774.028 MiB, 16.20% gc time)
# 34/49	[36, 36, 36, 36, 36, 36, 36, 36]	 30.215050 seconds (31.65 M allocations: 710.592 MiB, 19.13% gc time)
# 35/49	[36, 36, 36, 36, 36, 36, 36, 36]	 33.153490 seconds (37.24 M allocations: 830.300 MiB, 18.96% gc time)
# 36/49	[36, 36, 36, 36, 36, 36, 36, 36]	 46.882664 seconds (42.42 M allocations: 939.315 MiB, 14.62% gc time)
# 37/49	[37, 37, 37, 37, 37, 37, 37, 37]	 48.488470 seconds (47.73 M allocations: 1.030 GiB, 17.57% gc time)
# 38/49	[37, 37, 37, 37, 37, 37, 37, 37]	 44.316796 seconds (43.52 M allocations: 961.498 MiB, 20.18% gc time)
# 39/49	[37, 37, 37, 37, 37, 37, 37, 37]	 62.215793 seconds (50.20 M allocations: 1.089 GiB, 15.52% gc time)
# 40/49	[37, 37, 38, 38, 38, 38, 38, 38]	 51.910007 seconds (49.71 M allocations: 1.071 GiB, 20.86% gc time)
# 41/49	[38, 38, 38, 38, 38, 38, 38, 38]	 45.940570 seconds (42.18 M allocations: 946.137 MiB, 19.63% gc time)
# 42/49	[38, 38, 38, 38, 38, 38, 38, 38]	 65.403560 seconds (52.35 M allocations: 1.133 GiB, 15.46% gc time)
# 43/49	[38, 38, 38, 38, 38, 38, 38, 38]	 50.453387 seconds (47.57 M allocations: 1.027 GiB, 19.82% gc time)
# 44/49	[38, 39, 39, 39, 39, 39, 39, 39]	 58.735256 seconds (53.37 M allocations: 1.154 GiB, 18.71% gc time)
# 45/49	[39, 39, 39, 39, 39, 39, 39, 39]	 56.657201 seconds (50.92 M allocations: 1.096 GiB, 21.45% gc time)
# 46/49	[39, 39, 39, 39, 39, 39, 40, 40]	 53.587725 seconds (44.01 M allocations: 972.311 MiB, 15.55% gc time)
# 47/49	[40, 40, 40, 40, 40, 40, 40, 40]	 69.701199 seconds (63.11 M allocations: 1.362 GiB, 20.71% gc time)
# 48/49	[40, 40, 40, 40, 40, 40, 40, 40]	 77.531702 seconds (58.50 M allocations: 1.251 GiB, 16.94% gc time)
# 49/49	[40, 40, 40, 40, 40, 40, 40, 40]	 76.695460 seconds (58.31 M allocations: 1.259 GiB, 17.44% gc time)
# 1540.458177 seconds (1.39 G allocations: 30.285 GiB, 15.76% gc time)
# (392, 357, 0.9107142857142857)
#
# mean tree accuracy: 0.37244725763712816
#
# outer loop 1
# 1/44 2/44 3/44 4/44 5/44 6/44 7/44 8/44 9/44 10/44 11/44 12/44 13/44 14/44 15/44 16/44 17/44 18/44 19/44 20/44 21/44 22/44 23/44 24/44 25/44 26/44 27/44 28/44 29/44 30/44 31/44 32/44 33/44 34/44 35/44 36/44 37/44 38/44 39/44 40/44 41/44 42/44 43/44 44/44 1443.093168 seconds (265.75 M allocations: 6.914 GiB, 1.56% gc time)
# mean tree accuracy: 0.40374432065110794
#
# outer loop 2
# 1/44 2/44 3/44 4/44 5/44 6/44 7/44 8/44 9/44 10/44 11/44 12/44 13/44 14/44 15/44 16/44 17/44 18/44 19/44 20/44 21/44 22/44 23/44 24/44 25/44 26/44 27/44 28/44 29/44 30/44 31/44 32/44 33/44 34/44 35/44 36/44 37/44 38/44 39/44 40/44 41/44 42/44 43/44 44/44 1444.095627 seconds (292.02 M allocations: 7.498 GiB, 1.85% gc time)
# mean tree accuracy: 0.42662319570547136
#
# 2944.190052 seconds (575.23 M allocations: 14.862 GiB, 1.70% gc time)

# %% [markdown]
# ## Evaluation

# %%
lines = readlines("/Users/daniel/Documents/GitHub/iRealPro/compiled_tree_data.txt")
gold_names  = lines[collect(1:3:length(lines))]
gold_leafss = eval.(parse.(lines[collect(2:3:length(lines))]))
gold_trees  = tree.(lines[collect(3:3:length(lines))])
length(gold_trees)
# Out:
# 13

# %%
gold_names
# Out:
# 13-element Array{String,1}:
#  "allofme"
#  "anthropology"
#  "berniestune"
#  "beyondthebluehorizon"
#  "bluebossa"
#  "bluemoon"
#  "bluesforalice"
#  "canthelplovindatman"
#  "dreamalittledreamofme"
#  "flintstones"
#  "honeysucklerose"
#  "satindoll"
#  "sway"

# %%
@time meta_prior_accs = pmap(gold_leafss, gold_trees) do ls, t
    precision(convert(Tree, best_tree(run_chartparser(ls, meta_grammar_prior))), t)
end
mean(meta_prior_accs)
# Out:
#  28.402695 seconds (632.59 k allocations: 16.909 MiB, 1.64% gc time)
# 0.36304730549177516

# %%
@time meta_accs = pmap(gold_leafss, gold_trees) do ls, t
    precision(convert(Tree, best_tree(run_chartparser(ls, meta_grammar))), t)
end
mean(meta_accs)
# Out:
#  25.970617 seconds (1.52 M allocations: 40.277 MiB, 0.08% gc time)
# 0.4549048200995778

# %%
@time plain_prior_accs = pmap(gold_leafss, gold_trees) do ls, t
    precision(convert(Tree, best_tree(run_chartparser(ls, plain_grammar_prior))), t)
end
mean(plain_prior_accs)
# Out:
#  24.307919 seconds (755.49 k allocations: 20.496 MiB, 0.05% gc time)
# 0.36304730549177516

# %%
@time plain_accs = pmap(gold_leafss, gold_trees) do ls, t
    precision(convert(Tree, best_tree(run_chartparser(ls, plain_grammar))), t)
end
mean(plain_accs)
# Out:
#  27.676722 seconds (8.73 M allocations: 230.769 MiB, 1.12% gc time)
# 0.42662319570547136

# %%
right_baseline_grammar = begin
    implication = CFRule(['S']) do c
        ['S', 'A']
    end
    stop = CFRule(['S']) do c
        ['A']
    end
    termination = CFRule(['A']) do c
        ['a']
    end
    CFGrammar([implication, stop], [termination], ['S'])
end

right_branching_baseline_precisions = map(gold_trees, gold_leafss) do t, ls
    precision(convert(Tree, best_tree(run_chartparser(fill('a', length(ls)), right_baseline_grammar))), t)
end
mean(right_branching_baseline_precisions)
# Out:
# 0.08170094556657183

# %%
random_baseline_grammar = begin
    prolongation = CFRule(['A']) do c
        ['A', 'A']
    end
    termination = CFRule(['A']) do c
        ['a']
    end
    CFGrammar([prolongation], [termination], ['A'])
end

random_baseline_precisions = vcat(collect(
    map(gold_trees, gold_leafss) do t, ls
        precision(convert(Tree, sample_tree(run_chartparser(fill('a', length(ls)), random_baseline_grammar))), t)
    end
    for _ in 1:12
)...)
mean(random_baseline_precisions)
# Out:
# 0.15222316841294678

# %%
import DataFrames
import Seaborn
import Pandas
panda(df) = Pandas.DataFrame(Dict(n => df[n] for n in names(df)))

n = length(meta_accs)
df = vcat(
    DataFrame(accuracy=meta_accs, model=fill("PACFG", n), evaluation=fill("trained", n)),
    DataFrame(accuracy=meta_prior_accs, model=fill("PACFG", n), evaluation=fill("prior", n)),
    DataFrame(accuracy=plain_accs, model=fill("PCFG", n), evaluation=fill("trained", n)),
    DataFrame(accuracy=plain_prior_accs, model=fill("PCFG", n), evaluation=fill("prior", n)),
    DataFrame(accuracy=random_baseline_precisions, model=fill("random", 12n), evaluation=fill("trained", 12n)),
    DataFrame(accuracy=random_baseline_precisions, model=fill("random", 12n), evaluation=fill("prior", 12n)),
    DataFrame(accuracy=right_branching_baseline_precisions, model=fill("r-branch", n), evaluation=fill("trained", n)),
    DataFrame(accuracy=right_branching_baseline_precisions, model=fill("r-branch", n), evaluation=fill("prior", n)),
)
Seaborn.factorplot(data=panda(df), x=:evaluation, y=:accuracy, hue=:model, kind=:bar, palette=:Paired)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1657efdd8>)
# PyObject <seaborn.axisgrid.FacetGrid object at 0x169531400>

# %%
mean(meta_accs), mean(plain_accs)
# Out:
# (0.4549048200995778, 0.42662319570547136)

# %%
# mean(meta_accs), mean(plain_accs)
# Out:
# (0.4638610897448844, 0.4122222091962354)

# %% [markdown]
# ## Diagnostics

# %%
DataFrames.head(rules_data)
# Out:
# UndefVarError: rules_data not defined
#
# Stacktrace:
#  [1] include_string(::String, ::String) at ./loading.jl:522

# %%
number_steps = maximum(rules_data[:step])
# Out:
# 136

# %%
all_rules = unique(collect(zip(rules_data[:components], rules_data[:rule])))
# Out:
# 107-element Array{Tuple{String,String},1}:
#  ("(I, \"major\")", "CFRule(plagal_prep)")
#  ("(I, \"major\")", "CFRule(prolongation)")
#  ("(I, \"major\")", "CFRule(diatonic_subs)")
#  ("(I, \"major\")", "CFRule(diatonic_prep)")
#  ("(I, \"major\")", "CFRule(mode_change)")
#  ("(I, \"major\")", "CFRule(^7_termination)")
#  ("(I, \"major\")", "CFRule(^_termination)")
#  ("(I, \"major\")", "CFRule(6_termination)")
#  ("(I, \"minor\")", "CFRule(plagal_prep)")
#  ("(I, \"minor\")", "CFRule(prolongation)")
#  ("(I, \"minor\")", "CFRule(diatonic_subs)")
#  ("(I, \"minor\")", "CFRule(diatonic_prep)")
#  ("(I, \"minor\")", "CFRule(mode_change)")
#  ⋮
#  ("(VII, \"major\")", "CFRule(diatonic_prep)")
#  ("(VII, \"major\")", "CFRule(modulation)")
#  ("(VII, \"major\")", "CFRule(o7_termination)")
#  ("(VII, \"major\")", "CFRule(%7_termination)")
#  ("(VII, \"minor\")", "CFRule(dominant_prep)")
#  ("(VII, \"minor\")", "CFRule(prolongation)")
#  ("(VII, \"minor\")", "CFRule(diatonic_prep)")
#  ("(VII, \"minor\")", "CFRule(modulation)")
#  ("(VII, \"minor\")", "CFRule(+_termination)")
#  ("(VII, \"minor\")", "CFRule(7_termination)")
#  ("(VII, \"minor\")", "CFRule(sus_termination)")
#  ("(VII, \"minor\")", "CFRule(^_termination)")

# %%
function get_counts_by_time(components, rule)
    rules_data[
        (rules_data[:components] .== components) .& 
        (rules_data[:rule] .== rule) .&
        (rules_data[:step] .>= 0), 
        :count
    ]
end

for components in unique(first.(all_rules))[1:14]
    let components_and_rules = filter(c->c[1]==components, all_rules)
        display(
            Plots.plot(
                [get_counts_by_time(c_and_r...) for c_and_r in components_and_rules], 
                labels = getindex.(components_and_rules, 2), 
                title  = string(components), 
                legend = :topleft
            )
        )
    end
end
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip9400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9400)" points="
# 42.5104,375.869 580.315,375.869 580.315,31.4961 42.5104,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9402">
#     <rect x="42" y="31" width="539" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.417,375.869 137.417,31.4961
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   236.278,375.869 236.278,31.4961
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   335.139,375.869 335.139,31.4961
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   434,375.869 434,31.4961
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   532.862,375.869 532.862,31.4961
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,345.087 580.315,345.087
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,276.657 580.315,276.657
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,208.227 580.315,208.227
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,139.797 580.315,139.797
#   "/>
# <polyline clip-path="url(#clip9402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,71.3675 580.315,71.3675
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,375.869 42.5104,31.4961
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.417,375.869 137.417,370.703
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   236.278,375.869 236.278,370.703
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   335.139,375.869 335.139,370.703
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   434,375.869 434,370.703
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   532.862,375.869 532.862,370.703
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,345.087 50.5774,345.087
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,276.657 50.5774,276.657
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,208.227 50.5774,208.227
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,139.797 50.5774,139.797
#   "/>
# <polyline clip-path="url(#clip9400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,71.3675 50.5774,71.3675
#   "/>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.417, 389.669)" x="137.417" y="389.669">25</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 236.278, 389.669)" x="236.278" y="389.669">50</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 335.139, 389.669)" x="335.139" y="389.669">75</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 434, 389.669)" x="434" y="389.669">100</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 532.862, 389.669)" x="532.862" y="389.669">125</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 349.587)" x="36.5104" y="349.587">200</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 281.157)" x="36.5104" y="281.157">400</text>
# </g>
# <g clip-path="url(#clip9400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104,
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   434,375.869 434,31.4961
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   532.862,375.869 532.862,31.4961
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,311.705 580.315,311.705
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,247.41 580.315,247.41
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,183.115 580.315,183.115
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,118.82 580.315,118.82
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,54.5248 580.315,54.5248
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,375.869 42.5104,31.4961
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.417,375.869 137.417,370.703
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   236.278,375.869 236.278,370.703
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   335.139,375.869 335.139,370.703
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   434,375.869 434,370.703
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   532.862,375.869 532.862,370.703
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,311.705 50.5774,311.705
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,247.41 50.5774,247.41
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,183.115 50.5774,183.115
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,118.82 50.5774,118.82
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,54.5248 50.5774,54.5248
#   "/>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.417, 389.669)" x="137.417" y="389.669">25</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 236.278, 389.669)" x="236.278" y="389.669">50</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 335.139, 389.669)" x="335.139" y="389.669">75</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 434, 389.669)" x="434" y="389.669">100</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 532.862, 389.669)" x="532.862" y="389.669">125</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 316.205)" x="36.5104" y="316.205">500</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 251.91)" x="36.5104" y="251.91">1000</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 187.615)" x="36.5104" y="187.615">1500</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 123.32)" x="36.5104" y="123.32">2000</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 59.0248)" x="36.5104" y="59.0248">2500</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 311.413, 18)" x="311.413" y="18">(VII, &quot;minor&quot;)</text>
# </g>
# <polyline clip-path="url(#clip2002)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,235.708 46.4648,227.236 50.4193,220.27 54.3737,212.194 58.3282,214.902 62.2826,206.499 66.237,207.483 70.1915,216.008 74.1459,207.89 78.1004,210.269
#   82.0548,208.731 86.0093,210.131 89.9637,211.759 93.9182,220.842 97.8726,227.489 101.827,230.726 105.781,227.139 109.736,226.106 113.69,226.416 117.645,224.346
#   121.599,226.444 125.554,224.445 129.508,224.614 133.463,222.318 137.417,222.967 141.372,228.097 145.326,226.579 149.28,221.526 153.235,219.038 157.189,218.604
#   161.144,220.129 165.098,220.343 169.053,220.804 173.007,220.96 176.962,224.965 180.916,226.085 184.87,228.129 188.825,231.936 192.779,234.997 196.734,235.264
#   200.688,237.951 204.643,240.453 208.597,243.705 212.552,244.517 216.506,244.423 220.46,245.552 224.415,244.201 228.369,242.856 232.324,243.998 236.278,245.437
#   240.233,244.423 244.187,246.258 248.142,247.498 252.096,245.503 256.05,244.89 260.005,245.877 263.959,248.448 267.914,248.934 271.868,251.092 275.823,250.74
#   279.777,249.378 283.732,251.593 287.686,251.821 291.64,250.436 295.595,250.98

# %% [markdown]
# ## Tree accuracies

# %%
lines = readlines("/Users/daniel/Documents/GitHub/iRealPro/compiled_tree_data.txt")
gold_names  = lines[collect(1:3:length(lines))]
gold_leafss = eval.(parse.(lines[collect(2:3:length(lines))]))
gold_trees  = tree.(lines[collect(3:3:length(lines))]);

# %%
t = sample_tree(run_chartparser(gold_leafss[1], grammar))
# Out:
# [I_{G}[I_{g}[I_{g}[III_{g}[III_{g}[Bb^7]][III_{g}[VII_{g}[IV_{g}[V_{c}[G7]][IV_{g}[Cm7]]][VII_{g}[VII_{g}[F7]][VII_{g}[IV_{g}[V_{c}[V_{g}[I_{d}[Dm7]]][V_{c}[G7]]][IV_{g}[V_{c}[V_{g}[V_{c#}[V_{g#}[V_{eb}[V_{bb}[V_{f}[Cm7]][V_{bb}[F7]]][V_{eb}[V_{bb}[Fm7]][V_{eb}[Bb7]]]][V_{g#}[D#7]]][V_{c#}[G#7]]]][V_{c}[V_{g}[Dm7]][V_{c}[G7]]]][IV_{g}[Cm7]]]][VII_{g}[F7]]]]][III_{g}[Bb^7]]]]][I_{g}[V_{g}[V_{bb}[V_{f}[V_{c}[G7]][V_{f}[Cm7]]][V_{bb}[F7]]]][I_{g}[V_{g}[Dm7]][I_{g}[IV_{g}[V_{c}[G7]][IV_{g}[Cm7]]][I_{g}[I_{g}[V_{g}[V_{c#}[V_{g#}[V_{eb}[V_{bb}[F7]][V_{eb}[V_{bb}[Fm7]][V_{eb}[Bb7]]]][V_{g#}[D#7]]][V_{c#}[G#7]]]][I_{g}[III_{g}[VII_{g}[IV_{g}[Cm7]][VII_{g}[F7]]][III_{g}[Bb6]]]]][I_{g}[V_{g}[D7]][I_{g}[V_{g}[V_{g}[D7]][V_{g}[V_{c#}[V_{g#}[V_{eb}[V_{bb}[V_{f}[V_{c}[V_{c}[G7]][V_{c}[G7]]][V_{f}[C7]]][V_{bb}[V_{f}[II_{f}[IV_{f}[I_{bb}[V_{bb}[V_{f}[C7]][V_{bb}[V_{bb}[F7]][V_{bb}[F7]]]][I_{bb}[I_{Bb}[Bb^7]]]]]][V_{f}[V_{c}[G7]][V_{f}[Cm7]]]][V_{bb}[V_{bb}[F7]][V_{bb}[V_{f}[V_{c}[II_{c}[I_{d}[Dm7]]][V_{c}[G7]]][V_{f}[Cm7]]][V_{bb}[F7]]]]]][V_{eb}[V_{bb}[Fm7]][V_{eb}[Bb7]]]][V_{g#}[D#7]]][V_{c#}[G#7]]]]][I_{g}[III_{g}[VII_{g}[IV_{g}[Cm7]][VII_{g}[F7]]][III_{g}[Bb6]]]]]]]]]]]]

# %%
@everywhere function boolean_dependency_matrix(t::Tree)
    map(x-> x == "" ? false : true, dependency_matrix(t))
end

@everywhere function dependency_matrix(t::Tree)
    t = map(x->"x", t)
    k = add_leaf_indices!(t)
    add_inner_dependency_indices!(t)

    M = ["" for i in 1:k, j in 1:k]
    for node in t
        m = match(r"(.+) (\d+) (\d+)", node.data)
        M[parse(m[2]), parse(m[3])] = m[1]
    end
    M
end

@everywhere function add_leaf_indices!(tree::Tree)
    k = 1
    for node in tree
        if isleaf(node)
            node.data *= " $k $(k+1)"
            k += 1
        end
    end
    k # highest indices
end

@everywhere function add_inner_dependency_indices!(treenode::Tree)
    if !isleaf(treenode)
        m1 = match(r" (\d+) (\d+)", add_inner_dependency_indices!(treenode.children[1]).data)
        m2 = match(r" (\d+) (\d+)", add_inner_dependency_indices!(treenode.children[end]).data)
        treenode.data *= " $(m1[1]) $(m2[2])"
    end
    treenode
end

@everywhere Base.precision(proposal, goldstandard) =
    num_common_cons(proposal, goldstandard) / num_cons(proposal)
@everywhere recall(proposal, goldstandard) =
    num_common_cons(proposal, goldstandard) / num_cons(goldstandard)
@everywhere f1_measure(proposal, goldstandard) =
    2 * precision(proposal, goldstandard) * recall(proposal, goldstandard) /
       (precision(proposal, goldstandard) + recall(proposal, goldstandard))

@everywhere function num_cons(tree::Tree)
    M = boolean_dependency_matrix(tree)
    count(M) - size(M, 1)
end

@everywhere function num_common_cons(tree1::Tree, tree2::Tree)
    A = boolean_dependency_matrix(tree1)
    B = boolean_dependency_matrix(tree2)
    sum(a && b for (a,b) in zip(A,B)) - size(A, 1)
end

# %%
@time precisions_by_sequence = pmap(gold_leafss, gold_trees) do ls, t
    precision(convert(Tree, best_tree(run_chartparser(ls, grammar))), t)
end
# Out:
#  25.155975 seconds (4.90 M allocations: 133.071 MiB, 1.01% gc time)
# 10-element Array{Float64,1}:
#  0.448276
#  0.269231
#  0.512821
#  0.225806
#  0.37931
#  0.327273
#  0.353846
#  0.266667
#  0.530612
#  0.509434

# %%
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1872ffcf8>)
# PyObject <seaborn.axisgrid.FacetGrid object at 0x1872fffd0>

# %%
mean(precisions_by_sequence)
# Out:
# UndefVarError: precisions_by_sequence not defined
#
# Stacktrace:
#  [1] include_string(::String, ::String) at ./loading.jl:522

# %%
@time correct_cons_by_sequence = pmap(gold_leafss, gold_trees) do ls, t
    num_common_cons(convert(Tree, best_tree(run_chartparser(ls, grammar))), t)
end
sum(correct_cons_by_sequence) / sum(num_cons(t) for t in gold_trees)
# Out:
#  23.940756 seconds (4.91 M allocations: 133.285 MiB, 0.95% gc time)
# 0.38235294117647056

# %% [markdown]
# ## Prior accuracy

# %%
prior_grammar = init_jazz_grammar(identity);

# %%
@time prior_precisions = pmap(gold_leafss, gold_trees) do ls, t
    precision(convert(Tree, best_tree(run_chartparser(ls, prior_grammar))), t)
end
# Out:
#  22.608607 seconds (575.49 k allocations: 16.170 MiB)
# 10-element Array{Float64,1}:
#  0.0689655
#  0.615385
#  0.230769
#  0.290323
#  0.431034
#  0.309091
#  0.353846
#  0.444444
#  0.387755
#  0.490566

# %%
mean(prior_precisions)
# Out:
# 0.36221790739571796

# %% [markdown]
# ## Baseline

# %%
right_baseline_grammar = begin
    implication = CFRule(['S']) do c
        ['S', 'A']
    end
    stop = CFRule(['S']) do c
        ['A']
    end
    termination = CFRule(['A']) do c
        ['a']
    end
    CFGrammar([implication, stop], [termination], ['S'])
end

right_branching_baseline_precisions = map(gold_trees, gold_leafss) do t, ls
    precision(convert(Tree, best_tree(run_chartparser(fill('a', length(ls)), right_baseline_grammar))), t)
end

mean(right_branching_baseline_precisions)
# Out:
# 0.07892185194716608

# %%
left_baseline_grammar = begin
    implication = CFRule(['S']) do c
        ['A', 'S']
    end
    stop = CFRule(['S']) do c
        ['A']
    end
    termination = CFRule(['A']) do c
        ['a']
    end
    CFGrammar([implication, stop], [termination], ['S'])
end

left_branching_baseline_precisions = map(gold_trees, gold_leafss) do t, ls
    precision(convert(Tree, best_tree(run_chartparser(fill('a', length(ls)), left_baseline_grammar))), t)
end

mean(left_branching_baseline_precisions)
# Out:
# 0.0748707268373924

# %% [markdown]
# ## Circular parsing

# %%
tic()
toq()
println()
chords = terminals(iReal_songs[4, :chords])
run_chartparser(chords[1:5], grammar, cyclic=false)
run_chartparser(chords[1:5], grammar, cyclic=true)

linear_times = [
    begin
        tic()
        run_chartparser(chords[1:i], grammar, cyclic=false)
        toq()
    end
    for i in 1:30
]

cyclic_times = [
    begin
        tic()
        run_chartparser(chords[1:i], grammar, cyclic=true)
        toq()
    end
    for i in 1:30
]

# %%
Plots.plot([linear_times, cyclic_times])

# %%
p = Plots.plot(
    linear_times, cyclic_times, 
    xlabel = "linear parsing time in sec", 
    ylabel = "cyclic parsing time in sec", 
    label  = "parsing", 
    legend = :bottomright,
    title  = "Linear relationship between cyclic and linear parsing times")
Plots.plot!(p, x->3x+1.2, label="x --> 3x+1.2")

# %%
cyclic_runtime(n) = (cyclic_times[end] / 30^3) * n^3
linear_runtime(n) = (linear_times[end] / 30^3) * n^3

# %%
cyclic_runtime(60), linear_runtime(60)

# %% [markdown]
# ## Filter sequences that have m6 chords

# %%
# names of columns
print.(names(iReal_songs), '\t');

# %%
# all chord forms in the corpus
print.(unique(vcat(getindex.(iReal_songs[:chords], [:chordform])...)), '\t');

# %%
iReal_songs[:m6] = map(getindex.(iReal_songs[:chords], [:chordform])) do forms
    "m6" in forms
end

# number of songs that contain m6 chords
sum(iReal_songs[:m6]), size(iReal_songs, 1)

# %%
# plot histogram of chord sequencs lengths
sequence_lengths = size.(iReal_songs[:chords], 1)
Plots.histogram(sequence_lengths)

# %%
Plots.histogram(sequence_lengths, xlim=(0, 150), xticks=0:10:150)

# %%
count(n->n<=60, sequence_lengths), count(n->n<=60, sequence_lengths) / length(sequence_lengths)

# %% [markdown]
# $\sim 75\%$ of the sequences (877) consist of 60 or less chords.

# %%
# expected time for parsing all sequences of length 30 or shorter in minutes
sum(cyclic_runtime.(filter(n->n<=30, sequence_lengths))) / 60

# %%
# expected time for parsing all sequences of length 30 or shorter in hours
sum(cyclic_runtime.(filter(n->n<=60, sequence_lengths))) / 60 / 60

# %% [markdown]
# ## Print beginning and end of iReal sequences

# %%
k = 3
for i in 10*k+1:10*(k+1)
    println(i, '\t', iReal_songs[i, :key], '\t', iReal_songs[i, :title])
    println(terminals(iReal_songs[i, :chords])[1:10])
    println(terminals(iReal_songs[i, :chords])[end-9:end])
    println()
end

# %% [markdown]
# ## Write csv files for tree annotation

# %%
# write csv files for tree annotation
# 
# cd("/Users/daniel/Documents/GitHub/iRealPro/iReal_csv/")
# for (file, chords_df) in zip(iReal_songs[:file], iReal_songs[:chords])
#     open(splitext(file)[1]*".csv", "w") do f
#         print(f, chords_df[:bar][1])
#         for b in Iterators.drop(chords_df[:bar], 1)
#             print(f, ';', b)
#         end
#         print(f, '\n')
#         print(f, chords_df[:beat][1])
#         for b in Iterators.drop(chords_df[:beat], 1)
#             print(f, ';', b)
#         end
#         print(f, '\n')
#         print(f, terminals(chords_df)[1])
#         for t in Iterators.drop(terminals(chords_df), 1)
#             print(f, ';', t)
#         end
#     end
# end
